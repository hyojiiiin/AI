# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn import datasets, metrics
import tensorflow as tf

df = pd.read_csv('/content/drive/MyDrive/heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# 결측치 제거
df = df.dropna()
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = df.drop(columns=["target"])
y = df["target"]  # 라벨(label)

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: target, dtype: int64

# %%
Y = pd.get_dummies(y).values

# %%
X = X

# %%
X
# Out:
# array([[63.,  1.,  3., ...,  0.,  0.,  1.],
#        [37.,  1.,  2., ...,  0.,  0.,  2.],
#        [41.,  0.,  1., ...,  2.,  0.,  2.],
#        ...,
#        [68.,  1.,  0., ...,  1.,  2.,  3.],
#        [57.,  1.,  0., ...,  1.,  1.,  3.],
#        [57.,  0.,  1., ...,  1.,  1.,  2.]])

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
Y
# Out:
# array([[False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [False,  True],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False],
#        [ True, False]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (242, 13)

# %%
X_test.shape
# Out:
# (61, 13)

# %%
y_train.shape
# Out:
# (242, 2)

# %%
y_test.shape
# Out:
# (61, 2)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam


model = Sequential()
model.add(Dense(64, input_shape=(13,), activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(2, activation='softmax'))

model.compile(optimizer=Adam(learning_rate=0.04),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_28 (Dense)                     │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_30 (Dense)                     │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_31 (Dense)                     │ (None, 2)                   │              34 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,538 (13.82 KB)
#  Trainable params: 3,538 (13.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.5076 - loss: 27.4220 - val_accuracy: 0.5574 - val_loss: 4.1209
# Epoch 2/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5105 - loss: 2.5000 - val_accuracy: 0.4426 - val_loss: 0.8673
# Epoch 3/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4771 - loss: 0.7913 - val_accuracy: 0.5902 - val_loss: 0.6776
# Epoch 4/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5532 - loss: 0.6944 - val_accuracy: 0.4426 - val_loss: 0.6987
# Epoch 5/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5186 - loss: 0.7122 - val_accuracy: 0.5246 - val_loss: 0.6893
# Epoch 6/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.5789 - loss: 0.6973 - val_accuracy: 0.5574 - val_loss: 0.6822
# Epoch 7/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5719 - loss: 0.6874 - val_accuracy: 0.6721 - val_loss: 0.6763
# Epoch 8/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6130 - loss: 0.6766 - val_accuracy: 0.5738 - val_loss: 0.6670
# Epoch 9/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5846 - loss: 0.6709 - val_accuracy: 0.7213 - val_loss: 0.6602
# Epoch 10/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6540 - loss: 0.6606 - val_accuracy: 0.7377 - val_loss: 0.6422
# Epoch 11/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5706 - loss: 0.6673 - val_accuracy: 0.7541 - val_loss: 0.6208
# Epoch 12/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6603 - loss: 0.6395 - val_accuracy: 0.6885 - val_loss: 0.6159
# Epoch 13/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7269 - loss: 0.6156 - val_accuracy: 0.5574 - val_loss: 0.6841
# Epoch 14/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6154 - loss: 0.6504 - val_accuracy: 0.5574 - val_loss: 0.7629
# Epoch 15/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6348 - loss: 0.6879 - val_accuracy: 0.5574 - val_loss: 0.7885
# Epoch 16/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5748 - loss: 0.7667 - val_accuracy: 0.4754 - val_loss: 0.6786
# Epoch 17/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5491 - loss: 0.6659 - val_accuracy: 0.7869 - val_loss: 0.5936
# Epoch 18/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6953 - loss: 0.6116 - val_accuracy: 0.7541 - val_loss: 0.5551
# Epoch 19/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7199 - loss: 0.5602 - val_accuracy: 0.7049 - val_loss: 0.5449
# Epoch 20/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7315 - loss: 0.5982 - val_accuracy: 0.7869 - val_loss: 0.5126
# Epoch 21/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7510 - loss: 0.5266 - val_accuracy: 0.8197 - val_loss: 0.4517
# Epoch 22/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7332 - loss: 0.5347 - val_accuracy: 0.7213 - val_loss: 0.6719
# Epoch 23/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6803 - loss: 0.6346 - val_accuracy: 0.7377 - val_loss: 0.4746
# Epoch 24/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7137 - loss: 0.5594 - val_accuracy: 0.7541 - val_loss: 0.4810
# Epoch 25/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7245 - loss: 0.5807 - val_accuracy: 0.7541 - val_loss: 0.5159
# Epoch 26/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7677 - loss: 0.5073 - val_accuracy: 0.8197 - val_loss: 0.4410
# Epoch 27/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7704 - loss: 0.4750 - val_accuracy: 0.8197 - val_loss: 0.4246
# Epoch 28/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8191 - loss: 0.4104 - val_accuracy: 0.7377 - val_loss: 0.5592
# Epoch 29/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7196 - loss: 0.5067 - val_accuracy: 0.7869 - val_loss: 0.4176
# Epoch 30/30
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7675 - loss: 0.4337 - val_accuracy: 0.8361 - val_loss: 0.4123
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.74      0.80        27
#            1       0.82      0.91      0.86        34
#
#     accuracy                           0.84        61
#    macro avg       0.84      0.83      0.83        61
# weighted avg       0.84      0.84      0.83        61
#
# [[20  7]
#  [ 3 31]]
